# %% [markdown]
# # Jupyter Interface Setup Test
# This notebook verifies that Jupyter has been launched in the correct base directory (`sprint-3` root) and successfully interacts with the kernel.

# %%
print("Jupyter Notebook workspace is properly configured!")
# Out:
# Jupyter Notebook workspace is properly configured!
